# %%
#Importing libraries
import pandas as pd
from sqlalchemy import create_engine

# %%
#Connection with SQL
db_config = {'user': 'postgres',         # user name
             'pwd': '1234', # password
             'host': 'localhost',
             'port': 5432,              # connection port
             'db': 'My_Projects'}          # the name of the data base

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                                     db_config['pwd'],
                                                                       db_config['host'],
                                                                       db_config['port'],
                                                                       db_config['db'])

engine = create_engine(connection_string)

# %%
#Netflix table view
query = 'SELECT * FROM netflix'

netflix = pd.io.sql.read_sql(query, con = engine)
netflix.head(10)
# Out:
#                    title rating  \
# 0           White Chicks  PG-13
# 1    Lucky Number Slevin      R
# 2         Grey's Anatomy  TV-14
# 3           Prison Break  TV-14
# 4  How I Met Your Mother  TV-PG
# 5           Supernatural  TV-14
# 6           Breaking Bad  TV-MA
# 7    The Vampire Diaries  TV-14
# 8       The Walking Dead  TV-MA
# 9    Pretty Little Liars  TV-14
#
#                                          ratinglevel  ratingdescription  \
# 0  crude and sexual humor, language and some drug...                 80
# 1  strong violence, sexual content and adult lang...                100
# 2  Parents strongly cautioned. May be unsuitable ...                 90
# 3  Parents strongly cautioned. May be unsuitable ...                 90
# 4  Parental guidance suggested. May not be suitab...                 70
# 5  Parents strongly cautioned. May be unsuitable ...                 90
# 6  For mature audiences.  May not be suitable for...                110
# 7  Parents strongly cautioned. May be unsuitable ...                 90
# 8  For mature audiences.  May not be suitable for...                110
# 9  Parents strongly cautioned. May be unsuitable ...                 90
#
#    release year user rating score user rating size
# 0          2004                82               80
# 1          2006                NA               82
# 2          2016                98               80
# 3          2008                98               80
# 4          2014                94               80
# 5          2016                95               80
# 6          2013                97               80
# 7          2017                91               80
# 8          2015                98               80
# 9          2016                96               80

# %% [markdown]
# ## Query 1

# %%
#All shows with 'dead' titles
query = "select title from netflix where title ilike any(array['%%dead','dead%%','%%dead%%'])"

q1 = pd.io.sql.read_sql(query, con = engine)
q1
# Out:
#                    title
# 0       The Walking Dead
# 1  The Seven Deadly Sins
# 2       The Walking Dead
# 3         Drop Dead Diva
# 4         Drop Dead Diva

# %% [markdown]
# ## Query 2

# %%
#All R-rating shows on netflix
query = '''select COUNT(title),rating from netflix
where rating = 'R'
group by rating;'''

q2 = pd.io.sql.read_sql(query, con = engine)
q2
# Out:
#    count rating
# 0     19      R

# %% [markdown]
# ## Query 3

# %%
#Shows not suitable for childrens 
query = '''select rating_sub,count(distinct title) from( 
select title,
CASE when ratinglevel ilike '%%suitable for children%%' then replace(right(ratinglevel,13),'.','') 
	  when ratinglevel ilike '%%suitable for all children%%' then 'Not for children'
	  else null end as rating_sub 
from netflix ) as rating_shows
GROUP BY rating_sub;'''

q3 = pd.io.sql.read_sql(query, con = engine)
q3
# Out:
#          rating_sub  count
# 0      14 and under    100
# 1      17 and under     60
# 2      asy violence     25
# 3      for children     12
# 4  Not for children     31
# 5     s 7 and older     23
# 6              None    249

# %% [markdown]
# ## Query 4

# %%
#No. of shows released for Mature audience and childrens
query = '''select distinct(age_category),"release year" as year_of_release,count(title) as Show_count from
(select title,ratinglevel,"release year",
Case when ratinglevel ilike 'Suitable for children%%' then 'Children'
when ratinglevel ilike 'Suitable for all ages.' then 'everyone'
else 'Mature'
end as age_category
from netflix) as a
group by 1,2
order by 1,2;'''

q4 = pd.io.sql.read_sql(query, con = engine)
q4
# Out:
#    age_category  year_of_release  show_count
# 0      Children             1989           1
# 1      Children             1990           4
# 2      Children             1996           1
# 3      Children             1997           5
# 4      Children             1998           2
# ..          ...              ...         ...
# 63       Mature             2013          37
# 64       Mature             2014          48
# 65       Mature             2015          74
# 66       Mature             2016         254
# 67       Mature             2017          83
#
# [68 rows x 3 columns]

# %% [markdown]
# ## Query 5

# %%
#Best user-rated action shows
query = '''select distinct(title),case when "user rating score" = 'NA' then null else "user rating score" end as "user rating score",ratinglevel from netflix
where ratinglevel ilike '%%action%%'
order by 2 desc
nulls last
limit 10;'''

q5 = pd.io.sql.read_sql(query, con = engine)
q5
# Out:
#                              title user rating score  \
# 0                          The BFG                97
# 1                  The Jungle Book                97
# 2                         Zootopia                97
# 3  Alice Through the Looking Glass                96
# 4        Atlantis: The Lost Empire                96
# 5         Kubo and the Two Strings                96
# 6                          Minions                96
# 7                    Lilo & Stitch                95
# 8                             Home                94
# 9             Hotel Transylvania 2                93
#
#                                          ratinglevel
# 0  for action/peril, some scary moments and brief...
# 1       for some sequences of scary action and peril
# 2      some thematic elements, rude humor and action
# 3             fantasy action/peril and some language
# 4                                    action violence
# 5  thematic elements, scary images, action and peril
# 6                              action and rude humor
# 7                                 mild sci-fi action
# 8                    mild action and some rude humor
# 9           some scary images, action and rude humor

# %% [markdown]
# ## Query 6

# %%
#Movie contribution percentage per year
query = '''with movie_count as (
select count(distinct title) as numb,"release year" from netflix
group by 2
order by 1 desc
)
, percentage as (
	select "release year", round(numb / sum(numb) over (),2) *100  as percentage_of_total
	from movie_count
)
select * from percentage'''

q6 = pd.io.sql.read_sql(query, con = engine)
q6
# Out:
#     release year  percentage_of_total
# 0           2016                 29.0
# 1           2015                 12.0
# 2           2017                  7.0
# 3           2014                  7.0
# 4           2013                  7.0
# 5           2012                  5.0
# 6           2011                  3.0
# 7           2010                  3.0
# 8           2003                  2.0
# 9           2008                  2.0
# 10          2006                  2.0
# 11          2005                  2.0
# 12          2009                  2.0
# 13          1998                  2.0
# 14          1997                  2.0
# 15          2007                  2.0
# 16          2000                  1.0
# 17          2004                  1.0
# 18          2001                  1.0
# 19          1999                  1.0
# 20          1993                  1.0
# 21          2002                  1.0
# 22          1994                  1.0
# 23          1982                  0.0
# 24          1990                  0.0
# 25          1989                  0.0
# 26          1995                  0.0
# 27          1940                  0.0
# 28          1976                  0.0
# 29          1996                  0.0
# 30          1992                  0.0
# 31          1991                  0.0
# 32          1987                  0.0
# 33          1986                  0.0
# 34          1978                  0.0

# %% [markdown]
# ## Query 7

# %%
#Best user-rated comedy movies
query = '''select distinct(title),case when "user rating score" = 'NA' then null else "user rating score" end as "user rating score",ratinglevel from netflix
where ratinglevel ilike '%%humor%%'
order by 2 desc
nulls last
limit 10;'''

q7 = pd.io.sql.read_sql(query, con = engine)
q7
# Out:
#                    title user rating score  \
# 0                The BFG                97
# 1               Zootopia                97
# 2                Minions                96
# 3               Coraline                95
# 4              Bee Movie                94
# 5                   Home                94
# 6   Hotel Transylvania 2                93
# 7        Kung Fu Panda 3                92
# 8  The Angry Birds Movie                92
# 9           The Pacifier                91
#
#                                          ratinglevel
# 0  for action/peril, some scary moments and brief...
# 1      some thematic elements, rude humor and action
# 2                              action and rude humor
# 3  thematic elements, scary images, some language...
# 4                              mild suggestive humor
# 5                    mild action and some rude humor
# 6           some scary images, action and rude humor
# 7       martial arts action and some mild rude humor
# 8                          for rude humor and action
# 9           action violence, language and rude humor
